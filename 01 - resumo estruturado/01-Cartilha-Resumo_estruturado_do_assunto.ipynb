# %% [markdown]
# # ***Resumos estruturados do assunto***

# %% [markdown]
# A idéia principal é utilizar essas fontes primárias para um estudo profundo sobre o tema Línguagem de programação em Python.
#
# Acontece que, os livros que utilizei para estudos estão em algumas partes desatualizados (embora ainda sejam ótimos). Com isso, achei melhor trazer também a Documentação oficial do Python, utilizando-a e aplicando prompts claros ao NotebookLM para que, em casos de informações que não batam com o que a documentação oficial declara, ele me avise e então me ensine o que atualmente é utilizado, mas sabendo proveitar o que é afirmado pelos livros.
#
# Isso me garantirá que eu estarei utilizando uma "edição 2026" de cada livro, por assim dizer.
